# %% [markdown]
# ## 📝 Chap07-3. Stream output
#
# #### 터미널 창에서 스트림 방식으로 출력하기
# - 답변이 타이핑하듯이 출력되는 방식을 스트림 출력이라고 한다.
# - 일반적으로 사용하는 return은 한번에 결과를 반환하는 방식이라 yield로 수정.

# %% [markdown]
# ##### 결과값
# - ChatCompletionChunk 객체로 결과가 출력.

# %%
ChatCompletionChunk(
│   id='chatcmpl-EI8qfX6m54jNLwkVNuyDnf9WS35B2',
│   choices=[
│   │   Choice(
│   │   │   delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None),
│   │   │   finish_reason=None,
│   │   │   index=0,
│   │   │   logprobs=None
│   │   )
│   ],
│   created=1787992625,
│   model='gpt-4o-2024-08-06',
│   object='chat.completion.chunk',
│   moderation=None,
│   obfuscation='dEHolO6Wl7s',
│   service_tier='default',
│   system_fingerprint='fp_c9a0e786b8',
│   usage=None
)
ChatCompletionChunk(
│   id='chatcmpl-EI8qfX6m54jNLwkVNuyDnf9WS35B2',
│   choices=[
│   │   Choice(
│   │   │   delta=ChoiceDelta(content='안', function_call=None, refusal=None, role=None, tool_calls=None),
│   │   │   finish_reason=None,
│   │   │   index=0,
│   │   │   logprobs=None
│   │   )
│   ],
│   created=1787992625,
│   model='gpt-4o-2024-08-06',
│   object='chat.completion.chunk',
│   moderation=None,
│   obfuscation='VNci10RWP8Ch',
│   service_tier='default',
│   system_fingerprint='fp_c9a0e786b8',
│   usage=None
)
ChatCompletionChunk(
│   id='chatcmpl-EI8qfX6m54jNLwkVNuyDnf9WS35B2',
│   choices=[
│   │   Choice(
│   │   │   delta=ChoiceDelta(content='녕하세요', function_call=None, refusal=None, role=None, tool_calls=None),
│   │   │   finish_reason=None,
│   │   │   index=0,
│   │   │   logprobs=None
│   │   )
│   ],
│   created=1787992625,
│   model='gpt-4o-2024-08-06',
│   object='chat.completion.chunk',
│   moderation=None,
│   obfuscation='ViLuhsy1q',
│   service_tier='default',
│   system_fingerprint='fp_c9a0e786b8',
│   usage=None
)
ChatCompletionChunk(
│   id='chatcmpl-EI8qfX6m54jNLwkVNuyDnf9WS35B2',
│   choices=[
│   │   Choice(
│   │   │   delta=ChoiceDelta(content='!', function_call=None, refusal=None, role=None, tool_calls=None),
│   │   │   finish_reason=None,
│   │   │   index=0,
│   │   │   logprobs=None
│   │   )
│   ],
│   created=1787992625,
│   model='gpt-4o-2024-08-06',
│   object='chat.completion.chunk',
│   moderation=None,
│   obfuscation='iLbTMU8LNB2g',
│   service_tier='default',
│   system_fingerprint='fp_c9a0e786b8',
│   usage=None
)
ChatCompletionChunk(
│   id='chatcmpl-EI8qfX6m54jNLwkVNuyDnf9WS35B2',
│   choices=[
│   │   Choice(
│   │   │   delta=ChoiceDelta(content=' 저는', function_call=None, refusal=None, role=None, tool_calls=None),
│   │   │   finish_reason=None,
│   │   │   index=0,
│   │   │   logprobs=None
│   │   )
│   ],
│   created=1787992625,
│   model='gpt-4o-2024-08-06',
│   object='chat.completion.chunk',
│   moderation=None,
│   obfuscation='YCAaSYZ9Ey',
│   service_tier='default',
│   system_fingerprint='fp_c9a0e786b8',
│   usage=None
)
//...

# %% [markdown]
# #### 스트림 방식에서 펑션 콜링 사용하기
# - stream이 True인 상태에서 펑션 콜링을 사용하면 그 결과도 조각 단위로 반환된다.
# - 이렇게 출력되는 정보를 한데 모아야 한다.
#
# ##### 결과값

# %%
(chap07) PS C:\Users\ksol9\Documents\ksol927_ai_study\StudyRepo\learn_doit_llm_agent\chap07> streamlit run streamlit_chat_bot.py
2026-08-29 17:59:36.924 Uvicorn server started on :::8501

  You can now view your Streamlit app in your browser.

  Local URL: http://localhost:8501
  Network URL: http://211.250.198.194:8501

  Help agents write better Streamlit apps?
  Install the official Streamlit skills by running streamlit skills in your terminal.

안녕하세요! 무엇을 도와드릴까요?
===========
안녕하세요! 무엇을 도와드릴까요?
[]
AI      : 안녕하세요! 무엇을 도와드릴까요?
[{'id': 'call_67MfZTjBBWtuxvt2jMxdLWMz', 'function': {'arguments': '{"ticker": "MSFT", "period": "1mo"}', 'name': 'get_yf_stock_history'}, 'type': 'function'}, {'id': 'call_VeAGAhARoOBWKH12PjKIWUfG', 'function': {'arguments': '{"timezone": "America/Los_Angeles"}', 'name': 'get_current_time'}, 'type': 'function'}]

===========

[{'id': 'call_67MfZTjBBWtuxvt2jMxdLWMz', 'function': {'arguments': '{"ticker": "MSFT", "period": "1mo"}', 'name': 'get_yf_stock_history'}, 'type': 'function'}, {'id': 'call_VeAGAhARoOBWKH12PjKIWUfG', 'function': {'arguments': '{"timezone": "America/Los_Angeles"}', 'name': 'get_current_time'}, 'type': 'function'}]
| Date                      |    Open |    High |     Low |   Close |      Volume |   Dividends |   Stock Splits |
|:--------------------------|--------:|--------:|--------:|--------:|------------:|------------:|---------------:|
| 2026-07-29 00:00:00-04:00 | 392.661 | 400.496 | 388.01  | 389.806 | 4.7209e+07  |        0    |              0 |
| 2026-07-30 00:00:00-04:00 | 437.077 | 457.828 | 431.627 | 450.252 | 1.10161e+08 |        0    |              0 |
| 2026-07-31 00:00:00-04:00 | 449.154 | 465.963 | 448.486 | 463.847 | 6.0846e+07  |        0    |              0 |
| 2026-08-03 00:00:00-04:00 | 475.235 | 490.726 | 474.107 | 486.734 | 6.67621e+07 |        0    |              0 |
| 2026-08-04 00:00:00-04:00 | 479.996 | 498.502 | 478.27  | 491.884 | 5.04555e+07 |        0    |              0 |
| 2026-08-05 00:00:00-04:00 | 495.427 | 497.304 | 484.767 | 486.544 | 3.33889e+07 |        0    |              0 |
| 2026-08-06 00:00:00-04:00 | 487.632 | 500.618 | 487.602 | 498.921 | 3.64415e+07 |        0    |              0 |
| 2026-08-07 00:00:00-04:00 | 498.272 | 504.231 | 497.793 | 499.051 | 2.88462e+07 |        0    |              0 |
| 2026-08-10 00:00:00-04:00 | 502.494 | 512.765 | 501.326 | 505.109 | 3.12061e+07 |        0    |              0 |
| 2026-08-11 00:00:00-04:00 | 503.382 | 504.38  | 498.611 | 502.863 | 2.30498e+07 |        0    |              0 |
| 2026-08-12 00:00:00-04:00 | 499.051 | 500.558 | 490.596 | 491.505 | 2.90015e+07 |        0    |              0 |
| 2026-08-13 00:00:00-04:00 | 492.343 | 500.398 | 492.084 | 495.946 | 2.3039e+07  |        0    |              0 |
| 2026-08-14 00:00:00-04:00 | 495.427 | 499.071 | 492.992 | 494.469 | 1.62176e+07 |        0    |              0 |
| 2026-08-17 00:00:00-04:00 | 489.219 | 491.734 | 477.511 | 479.447 | 2.96358e+07 |        0    |              0 |
| 2026-08-18 00:00:00-04:00 | 480.635 | 483.36  | 476.253 | 480.725 | 2.40876e+07 |        0    |              0 |
| 2026-08-19 00:00:00-04:00 | 479.168 | 488.381 | 478.459 | 483.4   | 1.99619e+07 |        0    |              0 |
| 2026-08-20 00:00:00-04:00 | 483.3   | 484.16  | 479.5   | 481.15  | 2.00208e+07 |        0.91 |              0 |
| 2026-08-21 00:00:00-04:00 | 479.88  | 486.36  | 478.53  | 483.24  | 2.25108e+07 |        0    |              0 |
| 2026-08-24 00:00:00-04:00 | 483.21  | 490.61  | 481.86  | 487.31  | 1.72308e+07 |        0    |              0 |
| 2026-08-25 00:00:00-04:00 | 485.44  | 492.44  | 484.3   | 491.71  | 1.9519e+07  |        0    |              0 |
| 2026-08-26 00:00:00-04:00 | 487.85  | 497.4   | 487.31  | 496.37  | 2.07589e+07 |        0    |              0 |
| 2026-08-27 00:00:00-04:00 | 494.88  | 506.48  | 490.08  | 505.06  | 2.86888e+07 |        0    |              0 |
| 2026-08-28 00:00:00-04:00 | nan     | nan     | nan     | nan     | 2.89534e+07 |        0    |              0 |
2026-08-29 02:08:17 America/Los_Angeles
마이크로소프트(MSFT)의 최근 주가 추이는 다음과 같습니다:

- 2026년 8월 27일: 시작가 $494.88, 종가 $505.06
- 2026년 8월 26일: 시작가 $487.85, 종가 $496.37
- 2026년 8월 25일: 시작가 $485.44, 종가 $491.71

현재 마이크로소프트 본사가 있는 미국 워싱턴주의 레드몬드 시간은 2026년 8월 29일 오전 2시 8분입니다.

추가적인 질문이나 도움이 필요하시면 알려주세요!AI       : 마이크로소프트(MSFT)의 최근 주가 추이는 다음과 같습니다:

- 2026년 8월 27일: 시작가 $494.88, 종가 $505.06
- 2026년 8월 26일: 시작가 $487.85, 종가 $496.37
- 2026년 8월 25일: 시작가 $485.44, 종가 $491.71

현재 마이크로소프트 본사가 있는 미국 워싱턴주의 레드몬드 시간은 2026년 8월 29일 오전 2시 8분입니다.

추가적인 질문이나 도움이 필요하시면 알려주세요!
