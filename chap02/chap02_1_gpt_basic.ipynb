# %% [markdown]
# ## 📝 Chap02. GPT API 사용해보기

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')
client = OpenAI(api_key=api_key)

response = client.chat.completions.create(
  model="gpt-4o-mini",
  temperature=0.1, # 0.0 ~ 1.0, 낮을수록 더 결정적인 답변
  messages=[
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "2002년 한국은 월드컵 어디까지 진출했나요?"},
  ] # role은 system, user, assistant 중 하나
)

print(response)

print('----')
print(response.choices[0].message.content)
# Out:
# ChatCompletion(id='chatcmpl-EAvxbCTDGPA7fe9vXknpvaANyU9kl', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='2002년 한국은 FIFA 월드컵에서 4강에 진출했습니다. 이는 한국 축구 역사상 최초의 4강 진출로, 한국은 이 대회에서 포르투갈, 이탈리아, 스페인을 차례로 이기고 준결승에 진출했습니다. 준결승에서는 독일에 패하여 3위 결정전에서 터키와 맞붙었고, 그 경기에서 패하여 최종적으로 4위를 기록했습니다.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1786274787, model='gpt-4o-mini-2024-07-18', object='chat.completion', moderation=None, service_tier='default', system_fingerprint='fp_e7eb9f2bc2', usage=CompletionUsage(completion_tokens=102, prompt_tokens=32, total_tokens=134, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cache_write_tokens=None, cached_tokens=0)))
# ----
# 2002년 한국은 FIFA 월드컵에서 4강에 진출했습니다. 이는 한국 축구 역사상 최초의 4강 진출로, 한국은 이 대회에서 포르투갈, 이탈리아, 스페인을 차례로 이기고 준결승에 진출했습니다. 준결승에서는 독일에 패하여 3위 결정전에서 터키와 맞붙었고, 그 경기에서 패하여 최종적으로 4위를 기록했습니다.
